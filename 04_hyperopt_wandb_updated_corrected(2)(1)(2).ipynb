# %% [markdown]
# <a href="https://colab.research.google.com/github/MechalTimotewos/FBOFAC_Deep_Learning_Lab_Assignment/blob/main/04_hyperopt_wandb_updated_corrected(2)(1)(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Copyright
#
# <PRE>
# This notebook was created as part of the "Deep learning / VITMMA19" class at
# Budapest University of Technology and Economics, Hungary,
# https://portal.vik.bme.hu/kepzes/targyak/VITMMA19
#
# Any re-use or publication of any part of the notebook is only allowed with the
#  written consent of the authors.
#
# 2024 (c) Mohammed Salah Al-Radhi and Tamás Gábor Csapó (malradhi@tmit.bme.hu)
# </PRE>

# %%
### HYPEROPT: task during the class - we will do this together
# add WandB.ai integration to the code
# (help: https://docs.wandb.ai/guides/integrations/lightning )
# run at least 3 different trainings

# %%
# install pytorch lithening
# !pip install pytorch-lightning --quiet
# !pip install wandb --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 815.2/815.2 kB 15.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 869.5/869.5 kB 44.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 83.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 14.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.8/313.8 kB 21.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.9 MB/s eta 0:00:00

# %%
import pytorch_lightning as pl
import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import DataLoader,random_split
from torchmetrics import Accuracy
from torchvision import transforms
from torchvision.datasets import CIFAR10
from pytorch_lightning.loggers import WandbLogger
import wandb

# %%
# create one class to deal with data
class CifarDataModule(pl.LightningDataModule):
  def __init__(self, batch_size, data_dir="./"):
    super().__init__()
    self.data_dir=data_dir
    self.batch_size=batch_size
    self.transform=transforms.Compose([transforms.ToTensor(),transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))])
    self.num_classes=10

  def prepare_data(self):
    CIFAR10(self.data_dir,train=True,download=True)
    CIFAR10(self.data_dir,train=False,download=True)

  def setup(self, stage=None):
    if stage=='fit' or stage is None:
      cifar_full=CIFAR10(self.data_dir,train=True,transform=self.transform)
      self.cifar_train,self.cifar_val=random_split(cifar_full,[45000,5000])

    if stage=='test' or stage is None:
      self.cifar_test=CIFAR10(self.data_dir,train=False,transform=self.transform)

  def train_dataloader(self):
    return DataLoader(self.cifar_train,batch_size=self.batch_size,shuffle=True,num_workers=2)

  def val_dataloader(self):
    return DataLoader(self.cifar_val,batch_size=self.batch_size,shuffle=False,num_workers=2)

  def test_dataloader(self):
    return DataLoader(self.cifar_test,batch_size=self.batch_size,shuffle=False,num_workers=2)

# %%
class CIFAR10LitModel(pl.LightningModule):
    def __init__(self, input_shape,num_classes,learning_rate=3e-4):
      super().__init__()
      self.save_hyperparameters()
      self.input_shape=input_shape
      self.learning_rate=learning_rate

      # model architecture
      self.conv1=nn.Conv2d(3,32,3,1)
      self.conv2=nn.Conv2d(32,32,3,1)
      self.conv3=nn.Conv2d(32,64,3,1)
      self.conv4=nn.Conv2d(64,64,3,1)
      self.pool1=nn.MaxPool2d(2)
      self.pool2=nn.MaxPool2d(2)

      n_sizes = self._get_output_shape(input_shape)
      self.fc1=nn.Linear(n_sizes,512)
      self.fc2=nn.Linear(512,128)
      self.fc3=nn.Linear(128,num_classes)

      self.train_acc=Accuracy(task='multiclass',num_classes=10)
      self.val_acc=Accuracy(task='multiclass',num_classes=10)
      self.test_acc=Accuracy(task='multiclass',num_classes=10)


    def _get_output_shape(self, shape):
          '''returns the size of the output tensor from the conv layers'''
          batch_size = 1
          input = torch.autograd.Variable(torch.rand(batch_size, *shape))
          output_feat = self._feature_extractor(input)
          n_size = output_feat.data.view(batch_size, -1).size(1)
          return n_size


  # conv1,relu, conv2,relu, maxpool,conv3,relu,conv4,relu,maxpool
    def _feature_extractor(self,x):
      x=F.relu(self.conv1(x))
      x=self.pool1(F.relu(self.conv2(x)))
      x=F.relu(self.conv3(x))
      x=self.pool2(F.relu(self.conv4(x)))
      return x


    def forward(self,x):
      x=self._feature_extractor(x)
      x=x.view(x.size(0),-1)
      x=F.relu(self.fc1(x))
      x=F.relu(self.fc2(x))
      x=F.log_softmax(self.fc3(x),dim=1)
      return x

    def training_step(self, batch, batch_idx):
      x, y = batch
      logits = self(x)
      loss = F.nll_loss(logits, y)
      # metric
      preds = torch.argmax(logits, dim=1)
      acc = self.train_acc(preds, y)
      self.log('train_loss', loss, on_step=True, on_epoch=True, logger=True)
      self.log('train_acc', acc, on_step=True, on_epoch=True, logger=True)
      return loss

    # validation loop
    def validation_step(self, batch, batch_idx):
      x, y = batch
      logits = self(x)
      loss = F.nll_loss(logits, y)
      preds = torch.argmax(logits, dim=1)
      acc = self.val_acc(preds, y)
      self.log('val_loss', loss, prog_bar=True)
      self.log('val_acc', acc, prog_bar=True)
      return loss

    # test loop
    def test_step(self,batch,batch_idx):
      x,y=batch
      logits=self(x)
      loss=F.nll_loss(logits,y)

      pred=torch.argmax(logits,dim=1)
      acc=self.test_acc(pred,y)
      self.log('test_loss',loss,on_epoch=True)
      self.log('test_acc',acc,on_epoch=True)
      return loss

    def configure_optimizers(self):
      optimizer=torch.optim.Adam(self.parameters(),self.learning_rate)
      return optimizer

# %%
# class for visualizing one batch of validation images along with predicted and rall class label
class ImagePredictionLogger(pl.Callback):
    def __init__(self, val_samples, num_samples=32):
        super().__init__()
        self.val_imgs, self.val_labels = val_samples
        self.val_imgs = self.val_imgs[:num_samples]
        self.val_labels = self.val_labels[:num_samples]

    def on_validation_epoch_end(self, trainer, pl_module):
        val_imgs = self.val_imgs.to(device=pl_module.device)
        logits = pl_module(val_imgs)
        preds = torch.argmax(logits, 1)

        trainer.logger.experiment.log({
            "examples": [wandb.Image(x, caption=f"Pred:{pred}, Label:{y}")
                            for x, pred, y in zip(val_imgs, preds, self.val_labels)],
            "global_step": trainer.global_step
            })

# %%
# Instantiate the cifar and model
cifar = CifarDataModule(batch_size=32)
cifar.prepare_data()
cifar.setup()

# Grab samples to log predictions on
samples = next(iter(cifar.val_dataloader()))
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:03<00:00, 43643318.72it/s]
# Extracting ./cifar-10-python.tar.gz to ./
# Files already downloaded and verified

# %%
### WandB, you have have an account(if you don't, create one)
def train_model(learning_rate=1e-3):
    wandb.login(key='')
    config=wandb.config
    wandb_logger = WandbLogger(project='lastt', job_type='train', log_model="all")
    # instantiate classes
    dm = CifarDataModule(32)
    dm.prepare_data()
    dm.setup()
    model = CIFAR10LitModel((3, 32, 32), dm.num_classes, learning_rate)
    wandb_logger.watch(model)
    # Initialize Callbacks
    checkpoint_callback = pl.callbacks.ModelCheckpoint()
    early_stop_callback = pl.callbacks.EarlyStopping(monitor="val_acc", patience=3, verbose=False, mode="max")
    ### WandB
    trainer = pl.Trainer(max_epochs=5,
                     logger=wandb_logger,
                     callbacks=[checkpoint_callback, early_stop_callback,ImagePredictionLogger(samples)]
                    )
    # Train the model
    trainer.fit(model, dm)

    # Evaluate the model
    trainer.test(dataloaders=cifar.test_dataloader())
    # tell the WandB you have finished
    wandb.finish()

# %%
# Start training the model
train_model()
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Files already downloaded and verified
# Files already downloaded and verified
# wandb: Currently logged in as: mechal-timotewos (mechal-timotewos-budapest-university-of-technology-and-e). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.3
# Run data is saved locally in <code>./wandb/run-20241015_132957-74chhof9</code>
# Syncing run <strong><a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/lastt/runs/74chhof9' target="_blank">deep-shape-1</a></strong> to <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/lastt' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/lastt' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/lastt</a>
#  View run at <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/lastt/runs/74chhof9' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/lastt/runs/74chhof9</a>
# wandb: logging graph, to disable use `wandb.watch(log_graph=False)`
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# Files already downloaded and verified
# Files already downloaded and verified
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name      | Type               | Params | Mode
# ----------------------------------------------------------
# 0  | conv1     | Conv2d             | 896    | train
# 1  | conv2     | Conv2d             | 9.2 K  | train
# 2  | conv3     | Conv2d             | 18.5 K | train
# 3  | conv4     | Conv2d             | 36.9 K | train
# 4  | pool1     | MaxPool2d          | 0      | train
# 5  | pool2     | MaxPool2d          | 0      | train
# 6  | fc1       | Linear             | 819 K  | train
# 7  | fc2       | Linear             | 65.7 K | train
# 8  | fc3       | Linear             | 1.3 K  | train
# 9  | train_acc | MulticlassAccuracy | 0      | train
# 10 | val_acc   | MulticlassAccuracy | 0      | train
# 11 | test_acc  | MulticlassAccuracy | 0      | train
# ----------------------------------------------------------
# 952 K     Trainable params
# 0         Non-trainable params
# 952 K     Total params
# 3.809     Total estimated model params size (MB)
# 12        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=5` reached.
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/checkpoint_connector.py:145: `.test(ckpt_path=None)` was called without a model. The best model of the previous `fit` call will be used. You can pass `.test(ckpt_path='best')` to use the best model or `.test(ckpt_path='last')` to use the last model. If you pass a value, this warning will be silenced.
# Files already downloaded and verified
# Files already downloaded and verified
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at ./lastt/74chhof9/checkpoints/epoch=4-step=7035.ckpt
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:Loaded model weights from the checkpoint at ./lastt/74chhof9/checkpoints/epoch=4-step=7035.ckpt
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_acc          │    0.7203999757766724     │
# │         test_loss         │    0.8492377996444702     │
# └───────────────────────────┴───────────────────────────┘
# VBox(children=(Label(value='55.051 MB of 55.051 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▁▁▁▁▁▁▃▃▃▃▃▃▃▃▅▅▅▅▅▅▆▆▆▆▆▆█████████</td></tr><tr><td>global_step</td><td>▁▂▄▅▇█</td></tr><tr><td>test_acc</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>train_acc_epoch</td><td>▁▅▆▇█</td></tr><tr><td>train_acc_step</td><td>▁▄▄▅▅▅▅▅▆▆▅▅▆▅▆▅▇▆▆▆▆▆▆▆▆▇▇▆▆▇▇▇▇▆▆█▇█▇▇</td></tr><tr><td>train_loss_epoch</td><td>█▄▃▂▁</td></tr><tr><td>train_loss_step</td><td>█▇▇▆▆▅▄▄▅▅▅▄▄▅▄▄▃▄▃▃▃▃▄▃▃▃▄▃▄▃▃▃▃▃▁▁▂▁▂▂</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▂▂▂▂▂▃▄▄▄▅▅▅▅▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇██</td></tr><tr><td>val_acc</td><td>▁▅▇██</td></tr><tr><td>val_loss</td><td>█▄▂▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>global_step</td><td>7035</td></tr><tr><td>test_acc</td><td>0.7204</td></tr><tr><td>test_loss</td><td>0.84924</td></tr><tr><td>train_acc_epoch</td><td>0.78491</td></tr><tr><td>train_acc_step</td><td>0.84375</td></tr><tr><td>train_loss_epoch</td><td>0.6066</td></tr><tr><td>train_loss_step</td><td>0.57774</td></tr><tr><td>trainer/global_step</td><td>7035</td></tr><tr><td>val_acc</td><td>0.7126</td></tr><tr><td>val_loss</td><td>0.84588</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">deep-shape-1</strong> at: <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/lastt/runs/74chhof9' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/lastt/runs/74chhof9</a><br/> View project at: <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/lastt' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/lastt</a><br/>Synced 5 W&B file(s), 0 media file(s), 10 artifact file(s) and 193 other file(s)
# Find logs at: <code>./wandb/run-20241015_132957-74chhof9/logs</code>

# %%
### TASK OF THE STUDENT

# extend WandB.ai integration in the code with sweeps
# (e.g. add variables like learning rate, optimizer, neurons_FC1, neurons_FC2)
# help: https://docs.wandb.ai/guides/sweeps and
#       https://github.com/wandb/wandb/issues/5003
# store the hyperparameters and val_acc to wandb
# run at least 10 trainings
# in wandb.ai, export the result of the runs as a .csv file,
# in wandb.ai, create a report from the sweep results and share it by submitting
# the link in Moodle.

# %%
#By Gibiso Mechal Timotewos
#Neptune COde: FBOFAC

# %%
#sweep configuration
sweep_configuration = {
    'method': 'random',
    'metric': {
        'name': 'val_acc',
        'goal': 'maximize'
        },
    'parameters': {
        'learning_rate': {
            'values': [0.001, 0.0005, 0.0001]
            },
        'optimizer': {
            'values': ['adam', 'adamw','sgd']
            },
        'neurons_FC1': {
            'values': [64, 128, 256]
            },
        'neurons_FC2': {
            'values': [32, 64, 128]
            },
        'batch_size': {
            'values': [32, 64]
            }
        }
    }

# %%
# Create the sweep ID
sweep_id = wandb.sweep(sweep=sweep_configuration, project="mechal_last")
# Out:
# Create sweep with ID: 01o9sl2y
# Sweep URL: https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y

# %%
class LitCifarModel(pl.LightningModule):
    def __init__(self, neurons_FC1, neurons_FC2, learning_rate, optimizer):
        super().__init__()
        self.save_hyperparameters()

#Define the model
        self.model = nn.Sequential(
            nn.Flatten(),
            nn.Linear(32*32*3, neurons_FC1),
            nn.ReLU(),
            nn.Linear(neurons_FC1, neurons_FC2),
            nn.ReLU(),
            nn.Linear(neurons_FC2, 10)
        )

        #Define the loss function
        self.criterion = nn.CrossEntropyLoss()


      # Define the accuracy metric, specifying task and number of classes
        self.accuracy = Accuracy(task='multiclass', num_classes=10)

    def forward(self, x):
        return self.model(x)

    def training_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self(x)
        loss = self.criterion(y_hat, y)
        acc = self.accuracy(y_hat, y)
        self.log('train_loss', loss, on_step=True, on_epoch=True, logger=True)
        self.log('train_acc', acc, on_step=True, on_epoch=True, logger=True)
        return loss

    def validation_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self(x)
        loss = self.criterion(y_hat, y)
        acc = self.accuracy(y_hat, y)
        self.log('val_loss', loss, prog_bar=True)
        self.log('val_acc', acc, prog_bar=True)
        return loss


    def test_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self(x)
        loss = self.criterion(y_hat, y)
        acc = self.accuracy(y_hat, y)
        self.log('test_loss',loss,on_epoch=True)
        self.log('test_acc',acc,on_epoch=True)
        return loss



    def configure_optimizers(self):
      if self.hparams.optimizer == 'adam':
          return torch.optim.Adam(self.parameters(), lr=self.hparams.learning_rate)
      elif self.hparams.optimizer == 'adamw':
          return torch.optim.AdamW(self.parameters(), lr=self.hparams.learning_rate)
      elif self.hparams.optimizer == 'sgd':
          return torch.optim.SGD(self.parameters(), lr=self.hparams.learning_rate, momentum=0.9)

# %%
def train():
    # Initialize wandb run
    run = wandb.init()
    wandb_logger = WandbLogger(project="mechal_last")

    # Set up data
    data_module = CifarDataModule(batch_size=wandb.config.batch_size)

    # Model setup
    model = LitCifarModel(
        neurons_FC1=wandb.config.neurons_FC1,
        neurons_FC2=wandb.config.neurons_FC2,
        learning_rate=wandb.config.learning_rate,
        optimizer=wandb.config.optimizer
    )

    # Trainer
    trainer = pl.Trainer(max_epochs=10, logger=wandb_logger)
    trainer.fit(model, datamodule=data_module)

# %%
    # Start the WandB sweep
wandb.agent(sweep_id, function=train, count=10)
# Out:
# wandb: Agent Starting Run: plce8cv1 with config:
# wandb: 	batch_size: 64
# wandb: 	learning_rate: 0.001
# wandb: 	neurons_FC1: 64
# wandb: 	neurons_FC2: 32
# wandb: 	optimizer: adam
# Tracking run with wandb version 0.18.3
# Run data is saved locally in <code>/content/wandb/run-20241015_134518-plce8cv1</code>
# Syncing run <strong><a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/plce8cv1' target="_blank">stilted-sweep-1</a></strong> to <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y</a>
#  View project at <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last</a>
#  View sweep at <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y</a>
#  View run at <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/plce8cv1' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/plce8cv1</a>
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# Files already downloaded and verified
# Files already downloaded and verified
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name      | Type               | Params | Mode
# ---------------------------------------------------------
# 0 | model     | Sequential         | 199 K  | train
# 1 | criterion | CrossEntropyLoss   | 0      | train
# 2 | accuracy  | MulticlassAccuracy | 0      | train
# ---------------------------------------------------------
# 199 K     Trainable params
# 0         Non-trainable params
# 199 K     Total params
# 0.796     Total estimated model params size (MB)
# 9         Modules in train mode
# 0         Modules in eval mode
# wandb: WARNING Config item 'neurons_FC1' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'neurons_FC2' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# VBox(children=(Label(value='0.013 MB of 0.013 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▂▂▂▃▃▃▃▃▃▃▃▃▄▄▄▅▅▅▆▆▆▆▆▆▆▆▆▆▆▆▇▇██████</td></tr><tr><td>train_acc_epoch</td><td>▁▄▅▅▆▇▇▇██</td></tr><tr><td>train_acc_step</td><td>▃▁▄▃▂▄▄▅▅▃▄▅▄▄▆▅▅▆▄▅▄▇▆▇▅▇▇█▇▆▅▆▆▂▇▃█▃▆▇</td></tr><tr><td>train_loss_epoch</td><td>█▅▄▄▃▂▂▂▁▁</td></tr><tr><td>train_loss_step</td><td>█▇▆▆▅▅▅▄▄▄▅▃▄▄▃▃▄▂▄▃▃▃▂▂▃▄▃▂▃▃▃▃▃▃▂▁▃▁▂▂</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▃▃▃▃▃▃▃▄▄▄▄▄▄▄▄▄▅▅▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇█</td></tr><tr><td>val_acc</td><td>▁▄▇▆▆█▇▇▇█</td></tr><tr><td>val_loss</td><td>█▆▂▂▂▂▂▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>9</td></tr><tr><td>train_acc_epoch</td><td>0.59076</td></tr><tr><td>train_acc_step</td><td>0.64062</td></tr><tr><td>train_loss_epoch</td><td>1.16073</td></tr><tr><td>train_loss_step</td><td>1.16944</td></tr><tr><td>trainer/global_step</td><td>7039</td></tr><tr><td>val_acc</td><td>0.5096</td></tr><tr><td>val_loss</td><td>1.44094</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">stilted-sweep-1</strong> at: <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/plce8cv1' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/plce8cv1</a><br/> View project at: <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241015_134518-plce8cv1/logs</code>
# wandb: Agent Starting Run: si7eowys with config:
# wandb: 	batch_size: 64
# wandb: 	learning_rate: 0.0005
# wandb: 	neurons_FC1: 64
# wandb: 	neurons_FC2: 64
# wandb: 	optimizer: adamw
# Tracking run with wandb version 0.18.3
# Run data is saved locally in <code>/content/wandb/run-20241015_134832-si7eowys</code>
# Syncing run <strong><a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/si7eowys' target="_blank">elated-sweep-2</a></strong> to <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y</a>
#  View project at <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last</a>
#  View sweep at <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y</a>
#  View run at <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/si7eowys' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/si7eowys</a>
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# Files already downloaded and verified
# Files already downloaded and verified
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name      | Type               | Params | Mode
# ---------------------------------------------------------
# 0 | model     | Sequential         | 201 K  | train
# 1 | criterion | CrossEntropyLoss   | 0      | train
# 2 | accuracy  | MulticlassAccuracy | 0      | train
# ---------------------------------------------------------
# 201 K     Trainable params
# 0         Non-trainable params
# 201 K     Total params
# 0.806     Total estimated model params size (MB)
# 9         Modules in train mode
# 0         Modules in eval mode
# wandb: WARNING Config item 'neurons_FC1' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'neurons_FC2' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# VBox(children=(Label(value='0.013 MB of 0.013 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▁▁▂▂▃▃▃▃▃▃▃▃▄▄▄▄▄▅▅▅▆▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>train_acc_epoch</td><td>▁▄▅▅▆▇▇▇██</td></tr><tr><td>train_acc_step</td><td>▁▂▄▃▃▅▅▅▃▅▄▇█▃▆▄▅▆▄▇▅▅▇▅▇▅▅▆▅█▇▇▇▃▆▆▆▆▇█</td></tr><tr><td>train_loss_epoch</td><td>█▅▄▄▃▂▂▂▁▁</td></tr><tr><td>train_loss_step</td><td>█▇▅▇▆▆▅▄▅▄▅▃▄▅▅▆▆▃▄▄▆▃▄▄▄▃▅▃▄▅▃▄▃▅▁▂▃▄▁▄</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>val_acc</td><td>▁▃▄▅▇▆█▇██</td></tr><tr><td>val_loss</td><td>█▅▃▃▂▃▂▂▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>9</td></tr><tr><td>train_acc_epoch</td><td>0.5898</td></tr><tr><td>train_acc_step</td><td>0.67188</td></tr><tr><td>train_loss_epoch</td><td>1.16602</td></tr><tr><td>train_loss_step</td><td>1.09311</td></tr><tr><td>trainer/global_step</td><td>7039</td></tr><tr><td>val_acc</td><td>0.5164</td></tr><tr><td>val_loss</td><td>1.41121</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">elated-sweep-2</strong> at: <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/si7eowys' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/si7eowys</a><br/> View project at: <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241015_134832-si7eowys/logs</code>
# wandb: Agent Starting Run: 6uglv9y4 with config:
# wandb: 	batch_size: 32
# wandb: 	learning_rate: 0.0001
# wandb: 	neurons_FC1: 256
# wandb: 	neurons_FC2: 64
# wandb: 	optimizer: sgd
# Tracking run with wandb version 0.18.3
# Run data is saved locally in <code>/content/wandb/run-20241015_135140-6uglv9y4</code>
# Syncing run <strong><a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/6uglv9y4' target="_blank">ruby-sweep-3</a></strong> to <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y</a>
#  View project at <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last</a>
#  View sweep at <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y</a>
#  View run at <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/6uglv9y4' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/6uglv9y4</a>
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# Files already downloaded and verified
# Files already downloaded and verified
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name      | Type               | Params | Mode
# ---------------------------------------------------------
# 0 | model     | Sequential         | 803 K  | train
# 1 | criterion | CrossEntropyLoss   | 0      | train
# 2 | accuracy  | MulticlassAccuracy | 0      | train
# ---------------------------------------------------------
# 803 K     Trainable params
# 0         Non-trainable params
# 803 K     Total params
# 3.215     Total estimated model params size (MB)
# 9         Modules in train mode
# 0         Modules in eval mode
# wandb: WARNING Config item 'neurons_FC1' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'neurons_FC2' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# VBox(children=(Label(value='0.013 MB of 0.013 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▄▄▅▅▆▆▆▆▆▆▆▆▇▇█████</td></tr><tr><td>train_acc_epoch</td><td>▁▃▄▅▆▆▇▇██</td></tr><tr><td>train_acc_step</td><td>▁▂▂▅▅▄▃▄▅▃▃▂▅▅▄▅▇▄▆▄▆▅▅▄▃▅▅█▆▆▅▅▅▇▆▅█▆█▅</td></tr><tr><td>train_loss_epoch</td><td>█▇▅▄▃▃▂▂▁▁</td></tr><tr><td>train_loss_step</td><td>██▇▇▇▇▆▆▆▇▆▆▆▅▅▅▄▃▄▄▃▄▅▃▅▄▄▃▄▃▃▄▂▅▂▂▁▂▂▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▄▄▄▄▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇█</td></tr><tr><td>val_acc</td><td>▁▂▃▄▅▆▆▇▇█</td></tr><tr><td>val_loss</td><td>█▆▅▄▃▃▂▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>9</td></tr><tr><td>train_acc_epoch</td><td>0.38858</td></tr><tr><td>train_acc_step</td><td>0.28125</td></tr><tr><td>train_loss_epoch</td><td>1.73483</td></tr><tr><td>train_loss_step</td><td>1.91524</td></tr><tr><td>trainer/global_step</td><td>14069</td></tr><tr><td>val_acc</td><td>0.3928</td></tr><tr><td>val_loss</td><td>1.71056</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ruby-sweep-3</strong> at: <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/6uglv9y4' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/6uglv9y4</a><br/> View project at: <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241015_135140-6uglv9y4/logs</code>
# wandb: Agent Starting Run: jvm6a6us with config:
# wandb: 	batch_size: 64
# wandb: 	learning_rate: 0.0005
# wandb: 	neurons_FC1: 64
# wandb: 	neurons_FC2: 128
# wandb: 	optimizer: adamw
# Tracking run with wandb version 0.18.3
# Run data is saved locally in <code>/content/wandb/run-20241015_135539-jvm6a6us</code>
# Syncing run <strong><a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/jvm6a6us' target="_blank">splendid-sweep-4</a></strong> to <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y</a>
#  View project at <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last</a>
#  View sweep at <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y</a>
#  View run at <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/jvm6a6us' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/jvm6a6us</a>
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# Files already downloaded and verified
# Files already downloaded and verified
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name      | Type               | Params | Mode
# ---------------------------------------------------------
# 0 | model     | Sequential         | 206 K  | train
# 1 | criterion | CrossEntropyLoss   | 0      | train
# 2 | accuracy  | MulticlassAccuracy | 0      | train
# ---------------------------------------------------------
# 206 K     Trainable params
# 0         Non-trainable params
# 206 K     Total params
# 0.825     Total estimated model params size (MB)
# 9         Modules in train mode
# 0         Modules in eval mode
# wandb: WARNING Config item 'neurons_FC1' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'neurons_FC2' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# VBox(children=(Label(value='0.013 MB of 0.013 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▂▂▂▂▃▃▃▃▃▃▃▃▃▄▄▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇█████</td></tr><tr><td>train_acc_epoch</td><td>▁▃▄▅▆▆▇▇██</td></tr><tr><td>train_acc_step</td><td>▂▁▂▃▄▃▅▄▄▃▃▆▄▂▅▅▃▅▅█▄▅▅▅▆▃▆▃▅▄▄▅▆▆▇▆▄▄▆▄</td></tr><tr><td>train_loss_epoch</td><td>█▆▅▄▃▃▂▂▁▁</td></tr><tr><td>train_loss_step</td><td>██▆▇▆▆▆▄▅▅▄▄▄▅▄▄▅▄▃▃▃▅▂▃▄▃▄▁▂▁▅▃▃▂▃▃▂▂▄▄</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▃▃▃▃▃▃▄▄▄▄▄▄▄▄▄▅▅▅▅▅▅▅▅▅▅▆▆▆▇▇▇▇▇██</td></tr><tr><td>val_acc</td><td>▁▃▄▆▆▆█▇▇█</td></tr><tr><td>val_loss</td><td>█▅▅▂▂▂▁▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>9</td></tr><tr><td>train_acc_epoch</td><td>0.60491</td></tr><tr><td>train_acc_step</td><td>0.54688</td></tr><tr><td>train_loss_epoch</td><td>1.121</td></tr><tr><td>train_loss_step</td><td>1.30828</td></tr><tr><td>trainer/global_step</td><td>7039</td></tr><tr><td>val_acc</td><td>0.5208</td></tr><tr><td>val_loss</td><td>1.38865</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">splendid-sweep-4</strong> at: <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/jvm6a6us' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/jvm6a6us</a><br/> View project at: <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241015_135539-jvm6a6us/logs</code>
# wandb: Agent Starting Run: m1nxf78d with config:
# wandb: 	batch_size: 32
# wandb: 	learning_rate: 0.001
# wandb: 	neurons_FC1: 256
# wandb: 	neurons_FC2: 32
# wandb: 	optimizer: adamw
# Tracking run with wandb version 0.18.3
# Run data is saved locally in <code>/content/wandb/run-20241015_135857-m1nxf78d</code>
# Syncing run <strong><a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/m1nxf78d' target="_blank">polished-sweep-5</a></strong> to <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y</a>
#  View project at <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last</a>
#  View sweep at <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y</a>
#  View run at <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/m1nxf78d' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/m1nxf78d</a>
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# Files already downloaded and verified
# Files already downloaded and verified
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name      | Type               | Params | Mode
# ---------------------------------------------------------
# 0 | model     | Sequential         | 795 K  | train
# 1 | criterion | CrossEntropyLoss   | 0      | train
# 2 | accuracy  | MulticlassAccuracy | 0      | train
# ---------------------------------------------------------
# 795 K     Trainable params
# 0         Non-trainable params
# 795 K     Total params
# 3.181     Total estimated model params size (MB)
# 9         Modules in train mode
# 0         Modules in eval mode
# wandb: WARNING Config item 'neurons_FC1' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'neurons_FC2' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# VBox(children=(Label(value='0.013 MB of 0.013 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▃▃▃▃▄▄▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>train_acc_epoch</td><td>▁▃▄▅▆▆▇▇██</td></tr><tr><td>train_acc_step</td><td>▁▁▃▃▂▁▁▃▄▆▆▅▄▅▅▃▃▃▅▃▅▄▄▃▅▇▅▅▃▅▆▃▄▅▅▄█▇█▇</td></tr><tr><td>train_loss_epoch</td><td>█▆▅▄▃▃▂▂▁▁</td></tr><tr><td>train_loss_step</td><td>█▇▇▆▇▆▃▆▄▆▅▆▆▃▂▃▅▄▃▂▃▄▂▅▂▃▅▃▄▄▃▅▂▁▄▃▄▁▂▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>val_acc</td><td>▁▃▆▆▇▇▇▇▇█</td></tr><tr><td>val_loss</td><td>█▄▂▁▂▂▃▃▅▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>9</td></tr><tr><td>train_acc_epoch</td><td>0.65031</td></tr><tr><td>train_acc_step</td><td>0.75</td></tr><tr><td>train_loss_epoch</td><td>0.99011</td></tr><tr><td>train_loss_step</td><td>0.77768</td></tr><tr><td>trainer/global_step</td><td>14069</td></tr><tr><td>val_acc</td><td>0.5134</td></tr><tr><td>val_loss</td><td>1.47765</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">polished-sweep-5</strong> at: <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/m1nxf78d' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/m1nxf78d</a><br/> View project at: <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241015_135857-m1nxf78d/logs</code>
# wandb: Agent Starting Run: kkf2fin3 with config:
# wandb: 	batch_size: 32
# wandb: 	learning_rate: 0.001
# wandb: 	neurons_FC1: 128
# wandb: 	neurons_FC2: 128
# wandb: 	optimizer: adamw
# Tracking run with wandb version 0.18.3
# Run data is saved locally in <code>/content/wandb/run-20241015_140312-kkf2fin3</code>
# Syncing run <strong><a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/kkf2fin3' target="_blank">clear-sweep-6</a></strong> to <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y</a>
#  View project at <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last</a>
#  View sweep at <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y</a>
#  View run at <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/kkf2fin3' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/kkf2fin3</a>
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# Files already downloaded and verified
# Files already downloaded and verified
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name      | Type               | Params | Mode
# ---------------------------------------------------------
# 0 | model     | Sequential         | 411 K  | train
# 1 | criterion | CrossEntropyLoss   | 0      | train
# 2 | accuracy  | MulticlassAccuracy | 0      | train
# ---------------------------------------------------------
# 411 K     Trainable params
# 0         Non-trainable params
# 411 K     Total params
# 1.645     Total estimated model params size (MB)
# 9         Modules in train mode
# 0         Modules in eval mode
# wandb: WARNING Config item 'neurons_FC1' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'neurons_FC2' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# VBox(children=(Label(value='0.013 MB of 0.013 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▁▂▂▂▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▆▆▆▇▇▇▇██</td></tr><tr><td>train_acc_epoch</td><td>▁▃▄▅▆▆▇▇██</td></tr><tr><td>train_acc_step</td><td>▄▂▄▃▅▁▁▃▃▄▅▃▃▃▄▅▆▃▅▅▃▇▆▇▃▄▆▅▃▇▆▅▃▆▅▅█▅▇▅</td></tr><tr><td>train_loss_epoch</td><td>█▆▅▄▃▃▂▂▁▁</td></tr><tr><td>train_loss_step</td><td>▇▇█▅▆▅▃▄▄▇▆▄▅▆▆▅▅▆▄▃▄▃▆▅▄▁▂▃▃▁▃▂▃▄▁▃▃▃▄▂</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▁▂▂▂▂▂▂▂▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇█</td></tr><tr><td>val_acc</td><td>▁▃▅▅▇▇████</td></tr><tr><td>val_loss</td><td>█▄▃▂▂▂▁▂▂▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>9</td></tr><tr><td>train_acc_epoch</td><td>0.64664</td></tr><tr><td>train_acc_step</td><td>0.65625</td></tr><tr><td>train_loss_epoch</td><td>0.9967</td></tr><tr><td>train_loss_step</td><td>1.12293</td></tr><tr><td>trainer/global_step</td><td>14069</td></tr><tr><td>val_acc</td><td>0.519</td></tr><tr><td>val_loss</td><td>1.48016</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">clear-sweep-6</strong> at: <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/kkf2fin3' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/kkf2fin3</a><br/> View project at: <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241015_140312-kkf2fin3/logs</code>
# wandb: Agent Starting Run: ib6gbuj5 with config:
# wandb: 	batch_size: 32
# wandb: 	learning_rate: 0.001
# wandb: 	neurons_FC1: 128
# wandb: 	neurons_FC2: 128
# wandb: 	optimizer: adamw
# Tracking run with wandb version 0.18.3
# Run data is saved locally in <code>/content/wandb/run-20241015_140727-ib6gbuj5</code>
# Syncing run <strong><a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/ib6gbuj5' target="_blank">winter-sweep-7</a></strong> to <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y</a>
#  View project at <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last</a>
#  View sweep at <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y</a>
#  View run at <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/ib6gbuj5' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/ib6gbuj5</a>
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# Files already downloaded and verified
# Files already downloaded and verified
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name      | Type               | Params | Mode
# ---------------------------------------------------------
# 0 | model     | Sequential         | 411 K  | train
# 1 | criterion | CrossEntropyLoss   | 0      | train
# 2 | accuracy  | MulticlassAccuracy | 0      | train
# ---------------------------------------------------------
# 411 K     Trainable params
# 0         Non-trainable params
# 411 K     Total params
# 1.645     Total estimated model params size (MB)
# 9         Modules in train mode
# 0         Modules in eval mode
# wandb: WARNING Config item 'neurons_FC1' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'neurons_FC2' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# VBox(children=(Label(value='0.013 MB of 0.013 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▅▅▆▆▆▆▆▆▇▇▇███████</td></tr><tr><td>train_acc_epoch</td><td>▁▃▄▅▆▆▇▇██</td></tr><tr><td>train_acc_step</td><td>▂▃▅▄▁▁▅▆▅▃▆▃▆▄▅▅▆▃▄▅▄▄▆▆▄█▄▆▆▆▄▅▅▆▅▆▅▃▆▆</td></tr><tr><td>train_loss_epoch</td><td>█▆▅▄▃▃▂▂▁▁</td></tr><tr><td>train_loss_step</td><td>▅█▆▇██▆▆▆▆▆▃▅▄▄▃▄▃▂▄▃▄▂▂▄▃▄▄▂▃▃▂▃▂▃▅▃▄▁▂</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▁▁▂▂▂▂▃▃▄▄▄▄▄▄▄▄▅▅▅▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇▇█</td></tr><tr><td>val_acc</td><td>▁▄▅▆▇▆█▇▇▆</td></tr><tr><td>val_loss</td><td>█▅▄▃▂▃▁▄▅█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>9</td></tr><tr><td>train_acc_epoch</td><td>0.6434</td></tr><tr><td>train_acc_step</td><td>0.59375</td></tr><tr><td>train_loss_epoch</td><td>0.99407</td></tr><tr><td>train_loss_step</td><td>1.25795</td></tr><tr><td>trainer/global_step</td><td>14069</td></tr><tr><td>val_acc</td><td>0.5034</td></tr><tr><td>val_loss</td><td>1.53912</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">winter-sweep-7</strong> at: <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/ib6gbuj5' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/ib6gbuj5</a><br/> View project at: <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241015_140727-ib6gbuj5/logs</code>
# wandb: Agent Starting Run: zbfejgte with config:
# wandb: 	batch_size: 64
# wandb: 	learning_rate: 0.001
# wandb: 	neurons_FC1: 256
# wandb: 	neurons_FC2: 64
# wandb: 	optimizer: adam
# Tracking run with wandb version 0.18.3
# Run data is saved locally in <code>/content/wandb/run-20241015_141136-zbfejgte</code>
# Syncing run <strong><a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/zbfejgte' target="_blank">glowing-sweep-8</a></strong> to <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y</a>
#  View project at <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last</a>
#  View sweep at <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y</a>
#  View run at <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/zbfejgte' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/zbfejgte</a>
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# Files already downloaded and verified
# Files already downloaded and verified
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name      | Type               | Params | Mode
# ---------------------------------------------------------
# 0 | model     | Sequential         | 803 K  | train
# 1 | criterion | CrossEntropyLoss   | 0      | train
# 2 | accuracy  | MulticlassAccuracy | 0      | train
# ---------------------------------------------------------
# 803 K     Trainable params
# 0         Non-trainable params
# 803 K     Total params
# 3.215     Total estimated model params size (MB)
# 9         Modules in train mode
# 0         Modules in eval mode
# wandb: WARNING Config item 'neurons_FC1' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'neurons_FC2' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# VBox(children=(Label(value='0.013 MB of 0.013 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▃▃▃▃▃▃▃▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▆▆▇▇▇▇▇█████</td></tr><tr><td>train_acc_epoch</td><td>▁▃▄▅▅▆▇▇██</td></tr><tr><td>train_acc_step</td><td>▁▁▅▄▃▃▄▃▃▃▅▄▃▄▅▄▃▅▄▄▆█▅▇▅▆▇▅▆▆█▆▇▇▇▅▆▆▆▆</td></tr><tr><td>train_loss_epoch</td><td>█▆▅▄▄▃▃▂▁▁</td></tr><tr><td>train_loss_step</td><td>█▆█▇▅▇▄▄▆▅▄▄▄▆▅▃▃▄▅▄▄▄▃▄▄▄▂▂▃▃▂▂▂▁▃▁▁▃▃▂</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇███</td></tr><tr><td>val_acc</td><td>▁▅▆▇████▇█</td></tr><tr><td>val_loss</td><td>█▄▃▃▁▂▂▃▅▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>9</td></tr><tr><td>train_acc_epoch</td><td>0.67573</td></tr><tr><td>train_acc_step</td><td>0.65625</td></tr><tr><td>train_loss_epoch</td><td>0.91095</td></tr><tr><td>train_loss_step</td><td>1.0037</td></tr><tr><td>trainer/global_step</td><td>7039</td></tr><tr><td>val_acc</td><td>0.523</td></tr><tr><td>val_loss</td><td>1.47713</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">glowing-sweep-8</strong> at: <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/zbfejgte' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/zbfejgte</a><br/> View project at: <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241015_141136-zbfejgte/logs</code>
# wandb: Agent Starting Run: lko741ao with config:
# wandb: 	batch_size: 64
# wandb: 	learning_rate: 0.0005
# wandb: 	neurons_FC1: 128
# wandb: 	neurons_FC2: 32
# wandb: 	optimizer: adamw
# Tracking run with wandb version 0.18.3
# Run data is saved locally in <code>/content/wandb/run-20241015_141500-lko741ao</code>
# Syncing run <strong><a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/lko741ao' target="_blank">scarlet-sweep-9</a></strong> to <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y</a>
#  View project at <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last</a>
#  View sweep at <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y</a>
#  View run at <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/lko741ao' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/lko741ao</a>
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# Files already downloaded and verified
# Files already downloaded and verified
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name      | Type               | Params | Mode
# ---------------------------------------------------------
# 0 | model     | Sequential         | 397 K  | train
# 1 | criterion | CrossEntropyLoss   | 0      | train
# 2 | accuracy  | MulticlassAccuracy | 0      | train
# ---------------------------------------------------------
# 397 K     Trainable params
# 0         Non-trainable params
# 397 K     Total params
# 1.591     Total estimated model params size (MB)
# 9         Modules in train mode
# 0         Modules in eval mode
# wandb: WARNING Config item 'neurons_FC1' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'neurons_FC2' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# VBox(children=(Label(value='0.013 MB of 0.013 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▄▅▅▅▆▆▆▆▆▆▆▆▇▇████</td></tr><tr><td>train_acc_epoch</td><td>▁▃▅▅▆▆▇▇██</td></tr><tr><td>train_acc_step</td><td>▁▂▁▅▃▄▅▃▅▅▄▆▄▅▆▅▅▆▅▆▅▄▆▆▆▄▅█▅▄▆▆▆▆█▅▇▆▇▆</td></tr><tr><td>train_loss_epoch</td><td>█▆▅▄▃▃▂▂▁▁</td></tr><tr><td>train_loss_step</td><td>██▄▆▅▅▄▄▅▃▅▃▃▃▄▄▂▃▃▄▅▂▃▁▃▁▂▂▃▂▃▃▃▂▁▁▂▂▂▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▁▂▂▂▂▂▂▂▂▂▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇█</td></tr><tr><td>val_acc</td><td>▁▃▆▆▆▇▇▇█▇</td></tr><tr><td>val_loss</td><td>█▅▃▂▂▂▁▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>9</td></tr><tr><td>train_acc_epoch</td><td>0.62578</td></tr><tr><td>train_acc_step</td><td>0.65625</td></tr><tr><td>train_loss_epoch</td><td>1.06847</td></tr><tr><td>train_loss_step</td><td>1.12243</td></tr><tr><td>trainer/global_step</td><td>7039</td></tr><tr><td>val_acc</td><td>0.5158</td></tr><tr><td>val_loss</td><td>1.40193</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">scarlet-sweep-9</strong> at: <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/lko741ao' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/lko741ao</a><br/> View project at: <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241015_141500-lko741ao/logs</code>
# wandb: Agent Starting Run: 50eoczg3 with config:
# wandb: 	batch_size: 32
# wandb: 	learning_rate: 0.0001
# wandb: 	neurons_FC1: 256
# wandb: 	neurons_FC2: 64
# wandb: 	optimizer: adam
# Tracking run with wandb version 0.18.3
# Run data is saved locally in <code>/content/wandb/run-20241015_141823-50eoczg3</code>
# Syncing run <strong><a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/50eoczg3' target="_blank">eager-sweep-10</a></strong> to <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y</a>
#  View project at <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last</a>
#  View sweep at <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/sweeps/01o9sl2y</a>
#  View run at <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/50eoczg3' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/50eoczg3</a>
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# Files already downloaded and verified
# Files already downloaded and verified
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name      | Type               | Params | Mode
# ---------------------------------------------------------
# 0 | model     | Sequential         | 803 K  | train
# 1 | criterion | CrossEntropyLoss   | 0      | train
# 2 | accuracy  | MulticlassAccuracy | 0      | train
# ---------------------------------------------------------
# 803 K     Trainable params
# 0         Non-trainable params
# 803 K     Total params
# 3.215     Total estimated model params size (MB)
# 9         Modules in train mode
# 0         Modules in eval mode
# wandb: WARNING Config item 'neurons_FC1' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'neurons_FC2' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# VBox(children=(Label(value='0.013 MB of 0.013 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▃▃▃▃▃▃▃▃▃▃▄▄▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇█</td></tr><tr><td>train_acc_epoch</td><td>▁▃▄▅▆▆▇▇██</td></tr><tr><td>train_acc_step</td><td>▁▁▃▁▄▁▁▁▃▃▃▃▃▃▆▃▆▅▄▅▅█▆▅▂▅▅▄▅▅▄▇▄▅▇▇▆▄▅▆</td></tr><tr><td>train_loss_epoch</td><td>█▆▅▄▃▃▂▂▁▁</td></tr><tr><td>train_loss_step</td><td>█▄▅▅▆▆▃▆▆▅▇▄▃▅▅▅▂▅▅▃▄▃▅▄▄▃▅▃▂▃▃▁▂▂▅▂▁▃▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▃▃▃▃▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇█</td></tr><tr><td>val_acc</td><td>▁▃▅▆▆▇▇▇██</td></tr><tr><td>val_loss</td><td>█▅▄▃▂▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>9</td></tr><tr><td>train_acc_epoch</td><td>0.62482</td></tr><tr><td>train_acc_step</td><td>0.53125</td></tr><tr><td>train_loss_epoch</td><td>1.09364</td></tr><tr><td>train_loss_step</td><td>1.28339</td></tr><tr><td>trainer/global_step</td><td>14069</td></tr><tr><td>val_acc</td><td>0.5264</td></tr><tr><td>val_loss</td><td>1.37687</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">eager-sweep-10</strong> at: <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/50eoczg3' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last/runs/50eoczg3</a><br/> View project at: <a href='https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last' target="_blank">https://wandb.ai/mechal-timotewos-budapest-university-of-technology-and-e/mechal_last</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241015_141823-50eoczg3/logs</code>
